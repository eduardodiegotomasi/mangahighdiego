# %%
import pygame
from pygame.locals import *
from sys import exit
import math
import time
pygame.init()
pygame.display.set_caption('Sprites')
class Vapo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        #self.sprites.append(pygame.image.load('personagem.png'))

        self.sprites.append(pygame.image.load('menino.png'))
        self.sprites.append(pygame.image.load('menino.png'))
        self.sprites.append(pygame.image.load('menino.png'))
        self.sprites.append(pygame.image.load('menino.png'))
        self.sprites.append(pygame.image.load('menina.png'))
        self.sprites.append(pygame.image.load('menina.png'))
        self.sprites.append(pygame.image.load('menina.png'))
        self.sprites.append(pygame.image.load('menina.png'))
        self.sprites.append(pygame.image.load('menina.png'))
        self.sprites.append(pygame.image.load('menina.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.sprites.append(pygame.image.load('personagem.png'))
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image, (128, 64))

        self.rect = self.image.get_rect()
        self.rect.topleft = 200, 200

        self.animar = False

    def atacar(self):
        self.animar = True
        self.rect.topleft = 200, 200
    def update(self):
        if self.animar == True:
            self.atual = self.atual + 0.5
            if self.atual >= len(self.sprites):
                self.atual = 0
                self.animar = False
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image, (128, 64))



class Sapo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        #self.sprites.append(pygame.image.load('personagem.png'))

        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina2.png'))
        self.sprites.append(pygame.image.load('menina3.png'))
        self.sprites.append(pygame.image.load('menina3.png'))
        self.sprites.append(pygame.image.load('menina3.png'))
        self.sprites.append(pygame.image.load('menina3.png'))
        self.sprites.append(pygame.image.load('menina3.png'))
        self.sprites.append(pygame.image.load('menina3.png'))
        self.sprites.append(pygame.image.load('menina4.png'))
        self.sprites.append(pygame.image.load('menina4.png'))
        self.sprites.append(pygame.image.load('menina4.png'))
        self.sprites.append(pygame.image.load('menina4.png'))
        self.sprites.append(pygame.image.load('menina4.png'))
        self.sprites.append(pygame.image.load('menina5.png'))
        self.sprites.append(pygame.image.load('menina5.png'))
        self.sprites.append(pygame.image.load('menina5.png'))
        self.sprites.append(pygame.image.load('menina5.png'))
        self.sprites.append(pygame.image.load('menina5.png'))
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image, (128, 64))

        self.rect = self.image.get_rect()
        self.rect.topleft = 200, 100

        self.animar = False

    def atacar(self):
        self.animar = True
        self.rect.topleft = x, y
    def update(self):
        if self.animar == True:
            self.atual = self.atual + 0.5
            if self.atual >= len(self.sprites):
                self.atual = 0
                self.animar = False
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image, (128, 64))
class Suarez(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        #self.sprites.append(pygame.image.load('personagem.png'))

        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        self.sprites.append(pygame.image.load('suarez.png'))
        
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image, (128, 64))

        self.rect = self.image.get_rect()
        self.rect.topleft = 200, 100

        self.animar = False

    def atacar(self):
        self.animar = True
        self.rect.topleft = xsuarez, ysuarez
    def update(self):
        if self.animar == True:
            self.atual = self.atual + 0.5
            if self.atual >= len(self.sprites):
                self.atual = 0
                self.animar = False
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image, (128, 64))
class Bola(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        #self.sprites.append(pygame.image.load('personagem.png'))

        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        self.sprites.append(pygame.image.load('bola.png'))
        
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image, (20, 20))

        self.rect = self.image.get_rect()
        self.rect.topleft = 200, 100

        self.animar = False

    def atacar(self):
        self.animar = True
        self.rect.topleft = xbola, ybola
    def update(self):
        if self.animar == True:
            self.atual = self.atual + 0.5
            if self.atual >= len(self.sprites):
                self.atual = 0
                self.animar = False
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image, (128, 64))
class Gol(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        #self.sprites.append(pygame.image.load('personagem.png'))

        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        self.sprites.append(pygame.image.load('gol.png'))
        
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image, (80, 80))

        self.rect = self.image.get_rect()
        self.rect.topleft = 200, 100

        self.animar = False

    def atacar(self):
        self.animar = True
        self.rect.topleft = 500,200
    def update(self):
        if self.animar == True:
            self.atual = self.atual + 0.5
            if self.atual >= len(self.sprites):
                self.atual = 0
                self.animar = False
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image, (128, 64))


largura=640
altura= 480
tela=pygame.display.set_mode((largura,altura))
pygame.display.set_caption('penis')
x=0
y=0
xsuarez=0
ysuarez=0
xbola=0
ybola=0
movsuarez=0
movbola=0

relogio=pygame.time.Clock()
fonte=pygame.font.SysFont('arial',40,True,True)
pontos=0
mensagem=f'pontos{pontos}'
j=0
pygame.mixer.music.set_volume(1)
musicas=["videoplayback.mp3","dolls.mp3", "timbaland.mp3", "ramstein.mp3", "boney.mp3"]
musica_de_fundo=pygame.mixer.music.load(musicas[j])
pygame.mixer.music.play(-1)
todas_as_sprites = pygame.sprite.Group()
sapo = Sapo()
vapo = Vapo()
suarez=Suarez()
bola=Bola()
gol=Gol()
todas_as_sprites.add(sapo)
todas_as_sprites.add(vapo)
todas_as_sprites.add(suarez)
todas_as_sprites.add(bola)
todas_as_sprites.add(gol)
relogio = pygame.time.Clock()
tempo_atual=time.time()
tempo_final=tempo_atual+1
xbola=40
ybola=40
movbola=0
while True:
    if (time.time()>tempo_final):
        tempo_atual=time.time()
        tempo_final=tempo_atual+1
        if (movsuarez==0):
            xsuarez+=20
            ysuarez+=0
            if (xsuarez>largura):
                xsuarez-=30
                movsuarez=1
        if(movsuarez==1):
            xsuarez+=0
            ysuarez+=-20
            if (ysuarez<0):
                ysuarez+=30
                movsuarez=2
        if(movsuarez==2):
            xsuarez-=20
            ysuarez+=0
            if (xsuarez<0):
                xsuarez+=30
                movsuarez=3
        if(movsuarez==3):
            xsuarez+=0
            ysuarez+=20
            if (ysuarez>altura):
                xsuarez-=30
                movsuarez=0
                
        
    relogio.tick(30)
    tela.fill((0,0,0))
    ret_azul=pygame.draw.rect(tela,(255,0,0),(x,y,40,50))
    ret_vermelho=pygame.draw.rect(tela,(0,255,0),(200,200,40,50))
    ret_bola=pygame.draw.rect(tela,(0,0,255),(xbola,ybola,20,20))
    ret_gol=pygame.draw.rect(tela,(0,0,255),(500,200,200,200))
    texto=fonte.render(mensagem,True,(255,255,255))
    sapo.atacar()
    vapo.atacar()
    suarez.atacar()
    bola.atacar()
    gol.atacar()
    todas_as_sprites.draw(tela)
    todas_as_sprites.update()
    pygame.display.flip()
    if (movbola==1):
        xbola+=5
    if (movbola==2):
        xbola-=5
    if (movbola==3):
        ybola+=5
    if (movbola==4):
        ybola-=5
    if(xbola>largura):
        movbola=2
    if(xbola<0):
        movbola=1
    if(ybola>altura):
        movbola=4
    if(ybola<0):
        movbola=3
    if(ret_bola.colliderect(ret_gol)):
        movbola=0
        #x+=200
        #y+=200
        xbola=10
        ybola=10
        pontos+=1
        mensagem=f'pontos{pontos}'
        musica_de_fundo=pygame.mixer.music.load("olha.mp3")
        print(musicas[j])
        pygame.mixer.music.play(-1)
        j+=1
        if (j==4):
            j=0
    if(ret_gol.colliderect(ret_bola)):
        movbola=0
        #x+=200
        #y+=200
        pontos+=1
        mensagem=f'pontos{pontos}'
        musica_de_fundo=pygame.mixer.music.load("olha.mp3")
        print(musicas[j])
        pygame.mixer.music.play(-1)
        j+=1
        if (j==4):
            j=0
            
    for event in pygame.event.get():
        tela.blit(texto,(100,10))
        if event.type==QUIT:
            pygame.quit()
            exit()
        if event.type==KEYDOWN:
            #if event.key==K_DOWN:
             #   y+=10
            if event.key==K_RIGHT:
                x+=10
            if event.key==K_LEFT:
                x-=10
            if event.key==K_UP:
                y-=10
        sapo.atacar()
        todas_as_sprites.draw(tela)
        todas_as_sprites.update()
        pygame.display.flip()
        if pygame.key.get_pressed()[K_s]:
            y+=10
            if (movbola==0):
                ybola+=10
            sapo.atacar()
            todas_as_sprites.draw(tela)
            todas_as_sprites.update()
            pygame.display.flip()
        if pygame.key.get_pressed()[K_w]:
            y-=10
            sapo.atacar()
            if (movbola==0):
                ybola+=-10
            todas_as_sprites.draw(tela)
            todas_as_sprites.update()
            pygame.display.flip()
        if pygame.key.get_pressed()[K_d]:
            x+=10
            if (movbola==0):
                xbola+=10
            sapo.atacar()
            todas_as_sprites.draw(tela)
            todas_as_sprites.update()
            pygame.display.flip()
        if pygame.key.get_pressed()[K_a]:
            x-=10
            if (movbola==0):
                xbola+=-10
            sapo.atacar()
            todas_as_sprites.draw(tela)
            todas_as_sprites.update()
            pygame.display.flip()
        if pygame.key.get_pressed()[K_f]:
            if (movbola==0):
                xbola+=20
                movbola=1
            sapo.atacar()
            todas_as_sprites.draw(tela)
            todas_as_sprites.update()
            pygame.display.flip()
        if(ret_azul.colliderect(ret_bola)):
            movbola=0
        
            
            
            
            
            
        if(ret_vermelho.colliderect(ret_azul)):
            x+=200
            y+=200
            pontos+=1
            mensagem=f'pontos{pontos}'
            musica_de_fundo=pygame.mixer.music.load(musicas[j])
            print(musicas[j])
            pygame.mixer.music.play(-1)
            j+=1
            if (j==4):
                j=0
            sapo.atacar()
            todas_as_sprites.draw(tela)
            todas_as_sprites.update()
            pygame.display.flip()
            
        
    if(y>altura):
        y=0
    if(y<0):
        y=altura
    if(x>largura):
        x=0
    if(x<0):
        x=largura
    #pygame.draw.circle(tela,(255,255,0),(300,260),40)
    #pygame.draw.line(tela,(255,255,0),(200,10),(390,600),5)
    pygame.display.update()
# Out:
# videoplayback.mp3
# dolls.mp3
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
